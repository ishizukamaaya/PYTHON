# %% [markdown]
# <a href="https://colab.research.google.com/github/ishizukamaaya/PYTHON/blob/main/plt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# %matplotlib inline

# %%
volume = [10,20,30,20,10]
labels =['A','B','C','D','E']
plt.bar(labels, volume)
plt.show()

# %%
plt.bar(labels, volume, width=0.5)
plt.show()

# %%
plt.bar(labels, volume, width=1)
plt.show()

# %%
plt.barh(labels, volume)
plt.show()

# %%
plt.bar(labels, volume, color='#A9C3AD')
plt.show()

# %%
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue')
plt.show()

# %%
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue', linewidth=3)
plt.show()

# %%
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue')
plt.xlabel('Category')
plt.ylabel('Volume')
plt.show()

# %%
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue')
plt.xlabel('Category')
plt.ylabel('Volume')
plt.title('BarGraph')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue')
plt.xlabel('Category')
plt.ylabel('Volume')
plt.title('BarGraph')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(labels, volume, color='#A9C3AD', edgecolor='blue')
plt.xlabel('Category')
plt.ylabel('Volume')
plt.title('BarGraph')
plt.show()
plt.savefig('bargrapt.png')

# %%
labels = ['A','B','C','D','E']
man = [35,45,25,15,20]
woman = [20,25,30,40,30]

plt.bar(labels, man, width=0.4, align='edge', color='darkcyan')
plt.bar(labels, woman, width=0.4, align='center', color='coral')

plt.show()

# %%
plt.bar(labels, man, width=0.4, align='edge', color='darkcyan', label='Man')
plt.bar(labels, woman, width=0.4, align='center', color='coral', label='Woman')

plt.legend()
plt.show()

# %%
plt.bar(labels, man, width=0.4, align='edge', color='darkcyan', label='Man')
plt.bar(labels, woman, width=0.4, align='center', color='coral', label='Woman')

plt.xlabel('Category')
plt.ylabel('Numbrt of People')
plt.title('Man nad Woman')
plt.legend()
plt.show()

# %%
plt.bar(labels, man, width=0.4, color='darkcyan', label='Man')
plt.bar(labels, woman, width=0.4, color='coral', label='Woman', bottom=man)

plt.xlabel('Category')
plt.ylabel('Numbrt of People')
plt.title('Man nad Woman')
plt.legend()
plt.show()

# %%
plt.barh(labels, man, color='darkcyan', label='Man')
plt.barh(labels, woman, color='coral', label='Woman', left=man)

plt.xlabel('Category')
plt.ylabel('Numbrt of People')
plt.title('Man nad Woman')
plt.legend()
plt.show()

# %%
plt.barh(labels, man, height=0.4, color='darkcyan', label='Man')
plt.barh(labels, woman, height=0.4,  color='coral', label='Woman', left=man)

plt.xlabel('Category')
plt.ylabel('Numbrt of People')
plt.title('Man nad Woman')
plt.legend()
plt.show()
